# %% [markdown]
# <a href="https://colab.research.google.com/github/julianovale/PO450/blob/main/0001_VotacaoDeputados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url2019 = 'http://dadosabertos.camara.leg.br/arquivos/votacoesVotos/csv/votacoesVotos-2019.csv'
votacoes2019 = pd.read_csv(url2019, sep=';')
url2020 = 'http://dadosabertos.camara.leg.br/arquivos/votacoesVotos/csv/votacoesVotos-2020.csv'
votacoes2020 = pd.read_csv(url2020, sep=';')
url2021 = 'http://dadosabertos.camara.leg.br/arquivos/votacoesVotos/csv/votacoesVotos-2021.csv'
votacoes2021 = pd.read_csv(url2021, sep=';')

# %%
frames = [votacoes2019, votacoes2020, votacoes2021]
votacoes = pd.concat(frames)
votacoes
# Out:
#        idVotacao  ...                                   deputado_urlFoto
# 0      16526-506  ...  http://www.camara.gov.br/internet/deputado/ban...
# 1      16526-506  ...  http://www.camara.gov.br/internet/deputado/ban...
# 2      16526-506  ...  http://www.camara.gov.br/internet/deputado/ban...
# 3      16526-506  ...  http://www.camara.gov.br/internet/deputado/ban...
# 4      16526-506  ...  http://www.camara.gov.br/internet/deputado/ban...
# ...          ...  ...                                                ...
# 10015  2269710-9  ...  http://www.camara.gov.br/internet/deputado/ban...
# 10016  2269710-9  ...  http://www.camara.gov.br/internet/deputado/ban...
# 10017  2269710-9  ...  http://www.camara.gov.br/internet/deputado/ban...
# 10018  2269710-9  ...  http://www.camara.gov.br/internet/deputado/ban...
# 10019  2269710-9  ...  http://www.camara.gov.br/internet/deputado/ban...
#
# [290689 rows x 12 columns]

# %%
votacoes.columns.ravel()
# Out:
# array(['idVotacao', 'uriVotacao', 'dataHoraVoto', 'voto', 'deputado_id',
#        'deputado_uri', 'deputado_nome', 'deputado_siglaPartido',
#        'deputado_uriPartido', 'deputado_siglaUf',
#        'deputado_idLegislatura', 'deputado_urlFoto'], dtype=object)

# %%
df = votacoes[['idVotacao', 'voto', 'deputado_id','deputado_nome', 'deputado_siglaPartido','deputado_siglaUf']]
df = df.reset_index(drop=True)
df
# Out:
#         idVotacao voto  ...  deputado_siglaPartido deputado_siglaUf
# 0       16526-506  Não  ...                     PL               BA
# 1       16526-506  Não  ...                    PSL               SP
# 2       16526-506  Não  ...                   PSDB               BA
# 3       16526-506  Não  ...                   NOVO               SP
# 4       16526-506  Não  ...                     PP               GO
# ...           ...  ...  ...                    ...              ...
# 290684  2269710-9  Sim  ...                     PT               MA
# 290685  2269710-9  Sim  ...                     PT               BA
# 290686  2269710-9  Sim  ...          SOLIDARIEDADE               MG
# 290687  2269710-9  Sim  ...                     PL               MG
# 290688  2269710-9  Sim  ...                     PT               PR
#
# [290689 rows x 6 columns]

# %%
url = 'https://github.com/julianovale/PO450/blob/main/UFxREG.xlsx?raw=true'
ufxreg = pd.read_excel(url)
ufxreg
# Out:
#     COD_IBGE                    UF SIGLA_UF REG
# 0         11              Rondônia      RO    N
# 1         12                 Acre       AC    N
# 2         13              Amazonas       AM   N
# 3         14              Roraima       RR    N
# 4         15                 Pará       PA    N
# 5         16                Amapá       AP    N
# 6         17            Tocantins       TO    N
# 7         21             Maranhão        MA  NE
# 8         22                 Piauí       PI  NE
# 9         23                Ceará        CE  NE
# 10        24  Rio Grande do Norte       RN   NE
# 11        25              Paraíba       PB   NE
# 12        26           Pernambuco       PE   NE
# 13        27              Alagoas       AL   NE
# 14        28               Sergipe       SE  NE
# 15        29                 Bahia       BA  NE
# 16        31          Minas Gerais       MG  SE
# 17        32        Espírito Santo       ES  SE
# 18        33        Rio de Janeiro       RJ  SE
# ...

# %%
df = df.merge(ufxreg,left_on='deputado_siglaUf',right_on='SIGLA_UF')
df = df[['idVotacao', 'voto', 'deputado_id','deputado_nome', 'deputado_siglaPartido','deputado_siglaUf','REG']]
df
# Out:
#         idVotacao       voto  ...  deputado_siglaUf REG
# 0       16526-506        Não  ...                BA  NE
# 1       16526-506        Não  ...                BA  NE
# 2       16526-506  Obstrução  ...                BA  NE
# 3       16526-506  Obstrução  ...                BA  NE
# 4       16526-506  Obstrução  ...                BA  NE
# ...           ...        ...  ...               ...  ..
# 230531  2269710-9        Sim  ...                MT  CO
# 230532  2269710-9        Sim  ...                MT  CO
# 230533  2269710-9        Sim  ...                MT  CO
# 230534  2269710-9        Sim  ...                MT  CO
# 230535  2269710-9        Sim  ...                MT  CO
#
# [230536 rows x 7 columns]

# %%
df.isna().sum()
# Out:
# idVotacao                0
# voto                     0
# deputado_id              0
# deputado_nome            0
# deputado_siglaPartido    0
# deputado_siglaUf         0
# REG                      0
# dtype: int64
