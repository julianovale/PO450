# %% [markdown]
# <a href="https://colab.research.google.com/github/julianovale/PO450/blob/main/0003_Seade_Covid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importando bibliotecas

import pandas as pd

# %%
# lendo dados da seade

bases = ['01_populacao.csv', '02_mortalidadeinfantil.csv', '03_obitos.csv', '04_PIB.csv', 
         '05_valoradicionado.csv', '06_consumoenergiaeletrica.csv', '07_veiculos.csv', 
         '08_nascidosvivos.csv', '09_leitosinternacao.csv', '10_profissionaissaude.csv', 
         '11_empregosformais.csv', '12_rendaempregos.csv', '13_idhdimensoes.csv', 
         '14_rendapercapita.csv', '15_agualixoesgosto.csv']

url = 'https://raw.githubusercontent.com/julianovale/PO450/main/seade/'

for i in range(len(bases)):
  if i == 0:
    df = pd.read_csv(url+bases[i], delimiter = ';', encoding= 'Windows-1252')
  else:
    df = df.merge(pd.read_csv(url+bases[i], delimiter = ';', encoding= 'Windows-1252'),left_on='Cód. IBGE',right_on='Cód. IBGE')

# %%
df
# Out:
#             Localidades_x  ...  Esgoto Sanitário  Nível de Atendimento  Censo Demográfico (Em %)
# 0              Adamantina  ...                                              99.03
# 1                  Adolfo  ...                                              95.93
# 2                   Aguaí  ...                                              98.87
# 3          Águas da Prata  ...                                              87.99
# 4        Águas de Lindóia  ...                                              90.33
# ..                    ...  ...                                                ...
# 640  Vista Alegre do Alto  ...                                              99.74
# 641        Vitória Brasil  ...                                              97.19
# 642            Votorantim  ...                                              95.94
# 643           Votuporanga  ...                                              98.95
# ...

# %%
df.columns.ravel()
# Out:
# array(['Localidades_x', 'Períodos_x', 'População ',
#        'População Masculina ', 'População Feminina ', 'Razão de Sexos ',
#        'População Urbana ', 'População Rural ',
#        'Grau de Urbanização (Em %)', 'Cód. IBGE', 'Localidades_y',
#        'Períodos_y',
#        'Taxa de Mortalidade Infantil (Por mil nascidos vivos)',
#        'Taxa de Mortalidade Neonatal Precoce (Por mil nascidos vivos)',
#        'Taxa de Mortalidade Neonatal (Por mil nascidos vivos)',
#        'Taxa de Mortalidade Pós Neonatal (Por mil nascidos vivos)',
#        'Taxa de Mortalidade Neonatal Tardia (Por mil nascidos vivos)',
#        'Localidades_x', 'Períodos_x',
#        'Óbitos Gerais (por local de residência) ',
#        'Taxa de Mortalidade Geral (por local de residência) (Por mil habitantes)',
#        'Óbitos da População de 15 a 34 Anos ',
#        'Taxa de Mortalidade da População de 15 a 34 Anos (Por cem mil habitantes nessa faixa etária)',
# ...

# %%
df.isna().sum()
# Out:
# Localidades_x                                                            0
# Períodos_x                                                               0
# População                                                                0
# População Masculina                                                      0
# População Feminina                                                       0
#                                                                         ..
# Localidades                                                              0
# Períodos                                                                 0
# Abastecimento de Água  Nível de Atendimento  Censo Demográfico (Em %)    0
# Coleta de Lixo  Nível de Atendimento  Censo Demográfico (Em %)           0
# Esgoto Sanitário  Nível de Atendimento  Censo Demográfico (Em %)         0
# Length: 123, dtype: int64

# %%
df.dtypes
# Out:
# Localidades_x                                                             object
# Períodos_x                                                                 int64
# População                                                                  int64
# População Masculina                                                        int64
# População Feminina                                                         int64
#                                                                           ...
# Localidades                                                               object
# Períodos                                                                   int64
# Abastecimento de Água  Nível de Atendimento  Censo Demográfico (Em %)    float64
# Coleta de Lixo  Nível de Atendimento  Censo Demográfico (Em %)           float64
# Esgoto Sanitário  Nível de Atendimento  Censo Demográfico (Em %)         float64
# Length: 123, dtype: object

# %%
# baixando dados de Casos e Óbitos por município - diretamente do Github da Seade:
# Informações: https://github.com/seade-R/dados-covid-sp

url_casos_obitos = 'https://raw.githubusercontent.com/seade-R/dados-covid-sp/master/data/dados_covid_sp.csv'

df_casos_obitos = pd.read_csv(url_casos_obitos, delimiter = ';')
data_atual = df_casos_obitos['datahora'].max()
df_c_o_atual = df_casos_obitos[(df_casos_obitos['datahora']==data_atual)]
df_c_o_atual
# Out:
#               nome_munic  codigo_ibge  dia  ...  latitude longitude  semana_epidem
# 275415        Adamantina      3500105   27  ...  -21,6820  -51,0737             17
# 275416            Adolfo      3500204   27  ...  -21,2325  -49,6451             17
# 275417             Aguaí      3500303   27  ...  -22,0572  -46,9735             17
# 275418    Águas da Prata      3500402   27  ...  -21,9319  -46,7176             17
# 275419  Águas de Lindóia      3500501   27  ...  -22,4733  -46,6314             17
# ...                  ...          ...  ...  ...       ...       ...            ...
# 276056       Votuporanga      3557105   27  ...  -20,4237  -49,9781             17
# 276057          Zacarias      3557154   27  ...  -21,0506  -50,0552             17
# 276058         Chavantes      3557204   27  ...  -23,0366  -49,7096             17
# 276059      Estiva Gerbi      3557303   27  ...  -22,2713  -46,9481             17
# ...

# %%
# Abrir se necessário para estabilizar uma data.

# df_c_o_atual.to_csv('dados_covid_sp.csv', sep=";")
# from google.colab import files
# files.download('dados_covid_sp.csv')

# %%
# Alternativamente utilizar linhas abaixo para arquivo em meu Github com data-base 27/04/2021:
# Arquivo gerado pelo código acima

# url_casos_obitos = 'https://raw.githubusercontent.com/julianovale/PO450/main/seade/dados_covid_sp.csv'

# df_casos_obitos = pd.read_csv(url_casos_obitos, delimiter = ';')
# data_atual = df_casos_obitos['datahora'].max()
# df_c_o_atual = df_casos_obitos[(df_casos_obitos['datahora']==data_atual)]
# df_c_o_atual
