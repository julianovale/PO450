# %% [markdown]
# <a href="https://colab.research.google.com/github/julianovale/PO450/blob/main/Semana12_PO450.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image

# %%
n, m = 20,30
A = np.random.normal(size=(n,m))
rankA = np.linalg.matrix_rank(A)

UA, sA, VTA = np.linalg.svd(A)

plt.imshow(A)
plt.show()

# %%
plt.stem(sA)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """Entry point for launching an IPython kernel.

# %%
k = 5
G = np.random.normal(size=(n,k))
H = np.random.normal(size=(m,k))

B = np.dot(G, H.T)
rankB = np.linalg.matrix_rank(B)

plt.imshow(B)
plt.show()

# %%
UB, sB, VTB = np.linalg.svd(B)
plt.stem(sB)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %%
k = 1
G = np.random.normal(size=(n,k))
H = np.random.normal(size=(m,k))

B = np.dot(G, H.T)
rankB = np.linalg.matrix_rank(B)

plt.imshow(B)
plt.show()

# %%
UB, sB, VTB = np.linalg.svd(B)
plt.stem(sB)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %%
X = np.array(Image.open('download.jpeg').convert('L'))
plt.imshow(X);

# %%
rankX = np.linalg.matrix_rank(X)
UX, sX, VTX = np.linalg.svd(X)

# %%
rankX
# Out:
# 225

# %%
plt.stem(sX)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """Entry point for launching an IPython kernel.

# %%
p = 10
UX_p = UX[:,:p]
VTX_p = VTX[:p]
sX_p = sX[:p]
SX_p = np.diag(sX_p)

# %%
Xp = np.dot(UX_p,np.dot(SX_p,VTX_p))

# %%
plt.imshow(Xp);

# %%
plt.stem(sX_p)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """Entry point for launching an IPython kernel.
# <StemContainer object of 3 artists>

# %%
p = 15
UX_p = UX[:,:p]
VTX_p = VTX[:p]
sX_p = sX[:p]
SX_p = np.diag(sX_p)
Xp = np.dot(UX_p,np.dot(SX_p,VTX_p))

# %%
plt.imshow(Xp);

# %%
plt.stem(sX_p)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """Entry point for launching an IPython kernel.
# <StemContainer object of 3 artists>

# %%
N = X - Xp # aquilo que não foi explicado
plt.imshow(N);

# %%
X = np.array(Image.open('videira.jpg').convert('L'))
plt.imshow(X);

# %%
rankX = np.linalg.matrix_rank(X)
UX, sX, VTX = np.linalg.svd(X)

# %%
rankX
# Out:
# 495

# %%
plt.stem(sX)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """Entry point for launching an IPython kernel.

# %%
p = 30
UX_p = UX[:,:p]
VTX_p = VTX[:p]
sX_p = sX[:p]
SX_p = np.diag(sX_p)
Xp = np.dot(UX_p,np.dot(SX_p,VTX_p))
plt.imshow(Xp);

# %%
N = X - Xp # aquilo que não foi explicado
plt.imshow(N);
