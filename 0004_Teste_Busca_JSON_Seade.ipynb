# %% [markdown]
# <a href="https://colab.research.google.com/github/julianovale/PO450/blob/main/0004_Teste_Busca_JSON_Seade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Veja:
#
# http://doc.seade.gov.br/index.php/API-SEADE#Retorno_JSON_6

# %%
import json
from urllib.request import urlopen

# %%
path = 'http://api-imp.seade.gov.br/v1/perfil/1'
response = urlopen(path).read().decode('utf8')
data = json.loads(response)

# %%
data
# Out:
# {'perfil': [{'ano': {'2011': '354.136.119'},
#    'codigo_localidade': '1',
#    'codigo_localidade_pai': '701',
#    'codigo_variavel': '1',
#    'localidade': 'Adamantina',
#    'nome_localidade_pai': 'Região de Governo de Adamantina',
#    'periodo': '1985/1989-2011',
#    'unidade': '(Em reais de 2020)',
#    'variavel': 'Crédito Rural [Série interrompida]'},
#   {'ano': {'2011': '345.542.057'},
#    'codigo_localidade': '1',
#    'codigo_localidade_pai': '701',
#    'codigo_variavel': '2',
#    'localidade': 'Adamantina',
#    'nome_localidade_pai': 'Região de Governo de Adamantina',
#    'periodo': '1985/1989-2011',
#    'unidade': '(Em reais de 2020)',
#    'variavel': 'Crédito Rural Agricultura [Série interrompida]'},
#   {'ano': {'2011': '8.594.063'},
#    'codigo_localidade': '1',
#    'codigo_localidade_pai': '701',
#    'codigo_variavel': '3',
#    'localidade': 'Adamantina',
#    'nome_localidade_pai': 'Região de Governo de Adamantina',
#    'periodo': '1985/1989-2011',
# ...
