# %% [markdown]
# <a href="https://colab.research.google.com/github/julianovale/PO450/blob/main/ProjetoPO450.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importações de bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Importando dados

# %%
url = 'https://raw.githubusercontent.com/julianovale/PO450/main/seade/dados.csv'

df = pd.read_csv(url, delimiter = ';', decimal=',', encoding= 'Windows-1252')

# %%
df
# Out:
#      CodIBGE            Localidade  ...  LetalidCovid%  MortalidCovid%
# 0    3500105            Adamantina  ...       3.040057        0.250782
# 1    3500204                Adolfo  ...       2.449889        0.319118
# 2    3500303                 Aguaí  ...       3.144654        0.224669
# 3    3500402        Águas da Prata  ...       4.225352        0.269334
# 4    3500501      Águas de Lindóia  ...       2.232143        0.190487
# ..       ...                   ...  ...            ...             ...
# 640  3556909  Vista Alegre do Alto  ...       1.526718        0.124782
# 641  3556958        Vitória Brasil  ...       3.910615        0.397727
# 642  3557006            Votorantim  ...       4.382235        0.309621
# 643  3557105           Votuporanga  ...       2.872305        0.371622
# 644  3557154              Zacarias  ...       3.433476        0.312500
#
# [645 rows x 47 columns]

# %% [markdown]
# # Separando atributos e atributos-alvo

# %%
X = df[df.columns[3:-5]]
Y = df[['IncidCovid%','LetalidCovid%','MortalidCovid%']]

# %%
X
# Out:
#      Pop60mais%    DensDem  RazaoSexos  ...  Agua%   Lixo%  Esgoto%
# 0     21.842983   0.822690       92.89  ...  99.76   99.89    99.03
# 1     22.147846   0.163318       97.81  ...  96.76   99.72    95.93
# 2     14.616135   0.750353      100.88  ...  99.29   99.66    98.87
# 3     22.146791   0.546506       96.50  ...  95.84   99.38    87.99
# 4     17.762230   3.055713       94.78  ...  93.54   98.74    90.33
# ..          ...        ...         ...  ...    ...     ...      ...
# 640   13.681869   0.839778      103.85  ...  99.95   99.95    99.74
# 641   20.045429   0.353201      102.18  ...  98.27   99.57    97.19
# 642   13.573453   6.529207       97.93  ...  98.38   99.80    95.94
# 643   18.659768  21.811267       94.82  ...  99.50   99.79    98.95
# 644   18.686869   0.080236       98.46  ...  99.06  100.00    97.02
#
# [645 rows x 39 columns]

# %%
Y
# Out:
#      IncidCovid%  LetalidCovid%  MortalidCovid%
# 0       8.249248       3.040057        0.250782
# 1      13.025820       2.449889        0.319118
# 2       7.144462       3.144654        0.224669
# 3       6.374247       4.225352        0.269334
# 4       8.533798       2.232143        0.190487
# ..           ...            ...             ...
# 640     8.173197       1.526718        0.124782
# 641    10.170455       3.910615        0.397727
# 642     7.065363       4.382235        0.309621
# 643    12.938099       2.872305        0.371622
# 644     9.101562       3.433476        0.312500
#
# [645 rows x 3 columns]

# %% [markdown]
# # Normalizando dados e separando Ys

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X)
Y = scaler.fit_transform(Y)

# %%
dfY = pd.DataFrame(Y)
Y_I = dfY[0].to_numpy()
Y_L = dfY[1].to_numpy()
Y_M = dfY[2].to_numpy()

# %% [markdown]
# # Continua...
